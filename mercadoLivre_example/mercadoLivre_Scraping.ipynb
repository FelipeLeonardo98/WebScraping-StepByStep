# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeLeonardo98/WebScraping-StepByStep/blob/main/mercadoLivre_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://lista.mercadolivre.com.br/camisa-de-luta#D[A:camisa%20de%20luta]')
content = response.content

site = BeautifulSoup(content, 'html.parser')

divs = site.findAll('div', attrs={'class': 'ui-search-result__wrapper'})
for div in divs:
   title = div.find('a', attrs={'class': 'ui-search-item__group__element ui-search-link'})
   price = div.find('span', attrs={'class':'price-tag-text-sr-only'})
   print(titulo.text)
   print(price.text)
   print('------------------------------------------')
# Out:
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 165 reais con 90 centavos
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 38 reais con 90 centavos
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 39 reais
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 194 reais con 90 centavos
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 142 reais con 90 centavos
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 39 reais
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# 114 reais con 90 centavos
# ------------------------------------------
# Camisa Surf Lycra Rashguard Sunsetjetski Crossfit Luta Fpu50
# ...

# %%
# https://www.udemy.com/courses/search/?src=ukw&q=bigdata
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.tsurt.com.br/exclusivas/?mpage=5')
content = response.content

site = BeautifulSoup(content, 'html.parser')

course = site.find('img', attrs={'class':'lazyautosizes img-absolute'})

print(site.prettify())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
